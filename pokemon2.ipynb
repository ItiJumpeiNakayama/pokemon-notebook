# %%
# Importing all necessary libraries
import numpy as np
import pandas as pd
import cv2 as cv # pip install opencv-python
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import gc
import requests

from PIL import Image
from io import BytesIO

from collections import Counter
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense, Input
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
#from keras.applications.resnet50 import ResNet50
from keras.applications.xception import Xception
from keras.layers.pooling import GlobalAveragePooling2D

warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
# A little bit of data exploration
path = '/root/userspace/private/competition/dataset' # Path to directory which contains classes
classes = os.listdir(path) # List of all classes
print(f'Total number of categories: {len(classes)}')

# A dictionary which contains class and number of images in that class
counts = {}
for c in classes:
    counts[c] = len(os.listdir(os.path.join(path, c)))
    
print(f'Total number of images in dataset: {sum(list(counts.values()))}')

# Number of images in each clsss plot
fig = plt.figure(figsize = (25, 5))
sns.lineplot(x = list(counts.keys()), y = list(counts.values())).set_title('Number of images in each class')
plt.xticks(rotation = 90)
plt.margins(x=0)
plt.show()
# Out:
# Total number of categories: 149
# Total number of images in dataset: 10693

# %%
# Sort our "counts" dictionary and selecting 5 classes with most number of images
#imbalanced = sorted(counts.items(), key = lambda x: x[1], reverse = True)[:5]
imbalanced = sorted(counts.items(), key = lambda x: x[1], reverse = True)[:150]
print(imbalanced)

# Taking only labels, it will come in handy in future
imbalanced = [i[0] for i in imbalanced]
print(imbalanced)
# Out:
# [('Mewtwo', 307), ('Pikachu', 298), ('Charmander', 296), ('Bulbasaur', 289), ('Squirtle', 280), ('Psyduck', 159), ('Spearow', 130), ('Fearow', 124), ('Dratini', 109), ('Aerodactyl', 97), ('Rapidash', 83), ('Shellder', 81), ('Pidgey', 74), ('Ninetales', 74), ('Mankey', 72), ('Machamp', 72), ('Raichu', 71), ('Sandslash', 71), ('Muk', 71), ('Lapras', 71), ('Meowth', 70), ('Marowak', 70), ('Exeggutor', 70), ('Raticate', 70), ('Primeape', 70), ('Kingler', 69), ('Rhyhorn', 69), ('Growlithe', 69), ('Snorlax', 69), ('Vulpix', 68), ('Scyther', 68), ('Gyarados', 68), ('Vaporeon', 68), ('Nidoking', 68), ('Seadra', 67), ('Wigglytuff', 67), ('Lickitung', 67), ('Tauros', 67), ('Rattata', 67), ('Mew', 67), ('Golbat', 67), ('Vileplume', 67), ('Dewgong', 67), ('Kakuna', 67), ('Electrode', 67), ('Venomoth', 66), ('Nidoqueen', 66), ('Butterfree', 66), ('Pidgeot', 66), ('Venusaur', 66), ('Kabutops', 66), ('Oddish', 66), ('Ponyta', 66), ('Sandshrew', 66), ('Voltorb', 65), ('Koffing', 65), ('Seaking', 65), ('Metapod', 65), ('Charmeleon', 65), ('Dodrio', 65), ('Hitmonlee', 65), ('Poliwag', 65), ('Jigglypuff', 65), ('Dragonair', 65), ('Golem', 64), ('Poliwhirl', 64), ('Grimer', 64), ('Dugtrio', 64), ('Onix', 64), ('Jolteon', 64), ('Krabby', 64), ('Farfetchd', 64), ('Slowbro', 63), ('Tangela', 63), ('Nidorino', 63), ('Horsea', 63), ('Poliwrath', 63), ('Hypno', 63), ('Weezing', 63), ('Pinsir', 63), ('Kangaskhan', 63), ('Haunter', 63), ('Pidgeotto', 63), ('Arbok', 63), ('Moltres', 62), ('Blastoise', 62), ('Dragonite', 62), ('Wartortle', 61), ('Kadabra', 61), ('Arcanine', 61), ('Seel', 61), ('Golduck', 61), ('Hitmonchan', 61), ('Drowzee', 60), ('Staryu', 60), ('Slowpoke', 60), ('Gengar', 60), ('Zapdos', 60), ('Cloyster', 60), ('Magnemite', 60), ('Clefairy', 60), ('Nidorina', 59), ('Rhydon', 59), ('Cubone', 59), ('Magikarp', 59), ('Weedle', 59), ('Jynx', 59), ('Magneton', 59), ('Starmie', 59), ('Magmar', 59), ('MrMime', 59), ('Flareon', 59), ('Graveler', 58), ('Gloom', 58), ('Goldeen', 58), ('Chansey', 58), ('Omastar', 58), ('Persian', 57), ('Exeggcute', 57), ('Tentacool', 57), ('Venonat', 57), ('Tentacruel', 57), ('Kabuto', 56), ('Articuno', 56), ('Geodude', 56), ('Bellsprout', 55), ('Porygon', 55), ('Victreebel', 55), ('Omanyte', 55), ('Paras', 55), ('Electabuzz', 54), ('Machop', 53), ('Parasect', 53), ('Beedrill', 53), ('Ivysaur', 53), ('Charizard', 52), ('Ekans', 52), ('Machoke', 51), ('Diglett', 51), ('Weepinbell', 51), ('Gastly', 50), ('Caterpie', 50), ('Ditto', 49), ('Alakazam', 49), ('Zubat', 49), ('Clefable', 49), ('Doduo', 48), ('Abra', 42), ('Eevee', 41)]
# ['Mewtwo', 'Pikachu', 'Charmander', 'Bulbasaur', 'Squirtle', 'Psyduck', 'Spearow', 'Fearow', 'Dratini', 'Aerodactyl', 'Rapidash', 'Shellder', 'Pidgey', 'Ninetales', 'Mankey', 'Machamp', 'Raichu', 'Sandslash', 'Muk', 'Lapras', 'Meowth', 'Marowak', 'Exeggutor', 'Raticate', 'Primeape', 'Kingler', 'Rhyhorn', 'Growlithe', 'Snorlax', 'Vulpix', 'Scyther', 'Gyarados', 'Vaporeon', 'Nidoking', 'Seadra', 'Wigglytuff', 'Lickitung', 'Tauros', 'Rattata', 'Mew', 'Golbat', 'Vileplume', 'Dewgong', 'Kakuna', 'Electrode', 'Venomoth', 'Nidoqueen', 'Butterfree', 'Pidgeot', 'Venusaur', 'Kabutops', 'Oddish', 'Ponyta', 'Sandshrew', 'Voltorb', 'Koffing', 'Seaking', 'Metapod', 'Charmeleon', 'Dodrio', 'Hitmonlee', 'Poliwag', 'Jigglypuff', 'Dragonair', 'Golem', 'Poliwhirl', 'Grimer', 'Dugtrio', 'Onix', 'Jolteon', 'Krabby', 'Farfetchd', 'Slowbro', 'Tangela', 'Nidorino', 'Horsea', 'Poliwrath', 'Hypno', 'Weezing', 'Pinsir', 'Kangaskhan', 'Haunter', 'Pidgeotto', 'Arbok', 'Moltres', 'Blastoise', 'Dragonite', 'Wartortle', 'Kadabra', 'Arcanine', 'Seel', 'Golduck', 'Hitmonchan', 'Drowzee', 'Staryu', 'Slowpoke', 'Gengar', 'Zapdos', 'Cloyster', 'Magnemite', 'Clefairy', 'Nidorina', 'Rhydon', 'Cubone', 'Magikarp', 'Weedle', 'Jynx', 'Magneton', 'Starmie', 'Magmar', 'MrMime', 'Flareon', 'Graveler', 'Gloom', 'Goldeen', 'Chansey', 'Omastar', 'Persian', 'Exeggcute', 'Tentacool', 'Venonat', 'Tentacruel', 'Kabuto', 'Articuno', 'Geodude', 'Bellsprout', 'Porygon', 'Victreebel', 'Omanyte', 'Paras', 'Electabuzz', 'Machop', 'Parasect', 'Beedrill', 'Ivysaur', 'Charizard', 'Ekans', 'Machoke', 'Diglett', 'Weepinbell', 'Gastly', 'Caterpie', 'Ditto', 'Alakazam', 'Zubat', 'Clefable', 'Doduo', 'Abra', 'Eevee']

# %%
X = [] # List for images
Y = [] # List for labels

# Loop through all classes
for c in classes:
    # We take only classes that we defined in 'imbalanced' list
    if c in imbalanced:
        dir_path = os.path.join(path, c)
        label = imbalanced.index(c) # Our label is an index of class in 'imbalanced' list
        
        # Reading, resizing and adding image and label to lists
        for i in os.listdir(dir_path):
            image = cv.imread(os.path.join(dir_path, i))
            
            try:
                #resized = cv.resize(image, (96, 96)) # Resizing images to (96, 96)
                resized = cv.resize(image, (128, 128)) # Resizing images to (128, 128)
                X.append(resized)
                Y.append(label)
            
            # If we can't read image - we skip it
            except:
                print(os.path.join(dir_path, i), '[ERROR] can\'t read the file')
                continue       
            
print('DONE')
# Out:
# /root/userspace/private/competition/dataset/Venomoth/bb5d47bced6e4e33a77faa17e1eec906.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Nidoqueen/89a9c05292d84aeab91bb105da37e0c0.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Voltorb/94f443d834f94c1e8e6b088d879646d4.gif~c200 [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Graveler/3fe3c6a0bbd14de89092d2c675f743c1.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Fearow/8f2d7986ab76482fb76cac6a91b66de4.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Fearow/2c8d5221e92444f2b9477350e405bc54.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Kingler/a87633dcbf9643319da5d702e2e1a56c.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Scyther/a8734f10941a4deb95fcf7388e4fe8e2.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Exeggutor/f29b4f9fccff4055b167ece6556143cd.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Exeggutor/2b8bc491c5ca4e788999f8ea53617638.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Gyarados/6444e4ec716b44a4959bf97c1e75a935.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Hypno/ea34a7f7c68c467e8bf7240b26e0002c.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Zapdos/c99b2d19544c4cbbacd7711ade660279.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Golduck/bc08a691e7cb41b0bec2adf931dc9634.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Magneton/45e434d002bd44eeb1acbc2decc8ee0f.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Electabuzz/28a02c7a1389471693ff89712f1064f3.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Kabutops/01b54e83745340569cdde1442c8c429f.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Growlithe/f7a87c057dc94a32a0d5aedd1abed088.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Cloyster/ff270ebfab0f46b3b05c3fecd6a15ef9.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Caterpie/dcd36168d2bd470aaca333fb3bdf6bfa.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Poliwag/456c5063598a46a68a60ebcde5647ace.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Mewtwo/ed9eb0e7d3494c6992e06196f5b7cc05.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Venonat/56425d5f66e64584afbfc797b93c7ee5.ico [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Dewgong/e3ecbb47e192470aa8686734b7813b43.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Omastar/1be6e7da1bba4379b298b20013c57b4b.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Omastar/59761964ea084b4c85fc97837cd60fd8.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Machamp/546d68ace3ac414eb671b0e87880d683.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Tentacruel/d6fb0a3046364ea2b49525c6f6b966e5.svg [ERROR] can't read the file
# DONE

# %%
# Counting appearances of each label in labels list
obj = Counter(Y)

# Plotting number of images in each class
fig = plt.figure(figsize = (20, 5))
sns.barplot(x = [imbalanced[i] for i in obj.keys()], y = list(obj.values())).set_title('Number of images in each class')
plt.margins(x=0)
plt.show()

# %%
# Convert list with images to numpy array and reshape it 
#X = np.array(X).reshape(-1, 96, 96, 3)
X = np.array(X).reshape(-1, 128, 128, 3)

# Scaling data in array
X = X / 255.0

# Convert labels to categorical format
y = to_categorical(Y, num_classes = len(imbalanced))

# Splitting data to train and test datasets
# I'll use these datasets only for training, for final predictions I'll use random pictures from internet
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, shuffle = True, random_state = 666)

# %%
# Defining ImageDataGenerator Iinstance
datagen = ImageDataGenerator(rotation_range = 45, # Degree range for random rotations
                            zoom_range = 0.2, # Range for random zoom 
                            horizontal_flip = True, # Randomly flip inputs horizontally
                            width_shift_range = 0.15, # Range for horizontal shift 
                            height_shift_range = 0.15, # Range for vertical shift 
                            shear_range = 0.2) # Shear Intensity

datagen.fit(X_train)

# This piece of code can be used if you eant to look what your datagen doing with your images
# img = X[600]
# img = img.reshape([-1, 96, 96, 3])

# i = 0
# fig = plt.figure(figsize = (18, 8))

# for i, flow in enumerate(datagen.flow(img, batch_size = 1)):
#     fig.add_subplot(2, 5, i+1)
#     plt.imshow(np.squeeze(flow[:, :, ::-1]))
#     plt.axis('off')
#     i += 1
#     if i >= 10:
#         break

# %%
#model = Sequential()
#model.add(Conv2D(32, 3, padding = 'same', activation = 'relu', input_shape =(96, 96, 3), kernel_initializer = 'he_normal'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(128, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(128, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(256, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(256, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Flatten())
#model.add(Dense(512, activation = 'relu'))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))
#model.add(Dense(256, activation = 'relu'))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))
#model.add(Dense(len(imbalanced), activation = 'softmax'))
#
#model.summary()
#
##checkpoint = ModelCheckpoint('../working/best_model.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#checkpoint = ModelCheckpoint('/Users/nakayama/Desktop/lesson/advanced/work/pokemon/best_model.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#
#model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
##history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 100, validation_data = [X_test, y_test],
##                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])
#history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 10, validation_data = [X_test, y_test],
#                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])

#input_tensor = Input(shape=(96, 96, 3))
input_tensor = Input(shape=(128, 128, 3))
#base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=input_tensor)
base_model = Xception(include_top=False, weights='imagenet', input_tensor=input_tensor)

# 全結合層の新規構築
top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation = 'relu')(top_model)
predictions = Dense(len(imbalanced), activation = 'softmax')(top_model)

# ネットワーク定義
model = Model(inputs = base_model.input, outputs = predictions)

print("{}層".format(len(model.layers)))

# block12_sepconv1_act 層の手前まで freeze
trainable = False
for layer in model.layers:
    if layer.name == 'block12_sepconv1_act':
        trainable = True
    
    # block12_sepconv1_act 以降の層は freeze 解除
    layer.trainable = trainable

    # Batch Normalization の freeze 解除
    if layer.name.startswith('batch_normalization'):
        layer.trainable = True
    if layer.name.endswith('bn'):
        layer.trainable = True

##108層までfreeze
#for layer in model.layers[:108]:
#    layer.trainable = False
#
#    # Batch Normalization の freeze解除
#    if layer.name.startswith('batch_normalization'):
#        layer.trainable = True
#    if layer.name.endswith('bn'):
#        layer.trainable = True
#
##109層以降、学習させる
#for layer in model.layers[108:]:
#    layer.trainable = True

model.summary()

checkpoint = ModelCheckpoint('/root/userspace/private/competition/best_model_2.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#checkpoint = ModelCheckpoint('/root/userspace/private/competition/best_model.hdf5', verbose = 1, monitor = 'val_acc', save_best_only = True)

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# 135層
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 63, 63, 32)   864         input_2[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 63, 63, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 63, 63, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 61, 61, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 61, 61, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 61, 61, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 61, 61, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 61, 61, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 61, 61, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 61, 61, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 61, 61, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 31, 31, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 31, 31, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 31, 31, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 31, 31, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 31, 31, 128)  0           add_13[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 31, 31, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 31, 31, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 31, 31, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 31, 31, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 31, 31, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  32768       add_13[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 16, 16, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 16, 16, 256)  0           add_14[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 16, 16, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 16, 16, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 16, 16, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 16, 16, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 16, 16, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 728)    186368      add_14[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 8, 8, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 728)    2912        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 8, 8, 728)    0           add_15[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 8, 8, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 8, 8, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 8, 8, 728)    0           add_16[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 8, 8, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 8, 8, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 8, 8, 728)    0           add_17[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 8, 8, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 8, 8, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 8, 8, 728)    0           add_18[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 8, 8, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 8, 8, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 8, 8, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 8, 8, 728)    0           add_19[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 8, 8, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 8, 8, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 8, 8, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 8, 8, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 8, 8, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_20[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 8, 8, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 8, 8, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 8, 8, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_21[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 8, 8, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 8, 8, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 8, 8, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_22[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 8, 8, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 8, 8, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 8, 8, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 8, 8, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 8, 8, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 8, 8, 728)    0           add_23[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 8, 8, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 8, 8, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 8, 8, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 8, 8, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 8, 8, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 1024)   745472      add_23[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 4, 4, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 1024)   4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 4, 4, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 4, 4, 1536)   1582080     add_24[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 4, 4, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 4, 4, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 4, 4, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 4, 4, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 4, 4, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         2098176     global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 149)          152725      dense_3[0][0]
# ==================================================================================================
# Total params: 23,112,381
# Trainable params: 10,690,701
# Non-trainable params: 12,421,680
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 30, validation_data = [X_test, y_test],
                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])

# 性能評価
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 266/266 [==============================] - 67s 251ms/step - loss: 4.8495 - accuracy: 0.0541 - val_loss: 4.7072 - val_accuracy: 0.1210
#
# Epoch 00001: val_accuracy improved from -inf to 0.12096, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 2/50
# 266/266 [==============================] - 62s 234ms/step - loss: 3.6939 - accuracy: 0.1939 - val_loss: 3.1165 - val_accuracy: 0.2940
#
# Epoch 00002: val_accuracy improved from 0.12096 to 0.29395, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 3/50
# 266/266 [==============================] - 62s 233ms/step - loss: 2.5986 - accuracy: 0.3628 - val_loss: 2.1985 - val_accuracy: 0.4491
#
# Epoch 00003: val_accuracy improved from 0.29395 to 0.44913, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 4/50
# 266/266 [==============================] - 62s 233ms/step - loss: 1.9938 - accuracy: 0.4821 - val_loss: 1.8263 - val_accuracy: 0.5466
#
# Epoch 00004: val_accuracy improved from 0.44913 to 0.54665, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 5/50
# 266/266 [==============================] - 62s 233ms/step - loss: 1.5861 - accuracy: 0.5782 - val_loss: 1.9242 - val_accuracy: 0.5345
#
# Epoch 00005: val_accuracy did not improve from 0.54665
# Epoch 6/50
# 266/266 [==============================] - 62s 234ms/step - loss: 1.4030 - accuracy: 0.6191 - val_loss: 1.5421 - val_accuracy: 0.6207
#
# Epoch 00006: val_accuracy improved from 0.54665 to 0.62072, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 7/50
# 266/266 [==============================] - 62s 234ms/step - loss: 1.1739 - accuracy: 0.6722 - val_loss: 1.5597 - val_accuracy: 0.6156
#
# Epoch 00007: val_accuracy did not improve from 0.62072
# Epoch 8/50
# 266/266 [==============================] - 62s 234ms/step - loss: 1.0481 - accuracy: 0.7028 - val_loss: 1.4836 - val_accuracy: 0.6395
#
# Epoch 00008: val_accuracy improved from 0.62072 to 0.63947, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 9/50
# 266/266 [==============================] - 63s 236ms/step - loss: 0.9269 - accuracy: 0.7327 - val_loss: 1.3697 - val_accuracy: 0.6774
#
# Epoch 00009: val_accuracy improved from 0.63947 to 0.67745, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 10/50
# 266/266 [==============================] - 63s 236ms/step - loss: 0.8277 - accuracy: 0.7567 - val_loss: 1.3948 - val_accuracy: 0.6817
#
# Epoch 00010: val_accuracy improved from 0.67745 to 0.68167, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 11/50
# 266/266 [==============================] - 63s 235ms/step - loss: 0.7507 - accuracy: 0.7762 - val_loss: 1.4360 - val_accuracy: 0.6765
#
# Epoch 00011: val_accuracy did not improve from 0.68167
# Epoch 12/50
# 266/266 [==============================] - 62s 234ms/step - loss: 0.6713 - accuracy: 0.7976 - val_loss: 1.3656 - val_accuracy: 0.6840
#
# Epoch 00012: val_accuracy improved from 0.68167 to 0.68401, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 13/50
# 266/266 [==============================] - 62s 234ms/step - loss: 0.6056 - accuracy: 0.8145 - val_loss: 1.3899 - val_accuracy: 0.6981
#
# Epoch 00013: val_accuracy improved from 0.68401 to 0.69808, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 14/50
# 266/266 [==============================] - 62s 234ms/step - loss: 0.5799 - accuracy: 0.8248 - val_loss: 1.2663 - val_accuracy: 0.7093
#
# Epoch 00014: val_accuracy improved from 0.69808 to 0.70933, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 15/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.5283 - accuracy: 0.8355 - val_loss: 1.4118 - val_accuracy: 0.6840
#
# Epoch 00015: val_accuracy did not improve from 0.70933
# Epoch 16/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.4922 - accuracy: 0.8487 - val_loss: 1.3520 - val_accuracy: 0.7075
#
# Epoch 00016: val_accuracy did not improve from 0.70933
# Epoch 17/50
# 266/266 [==============================] - 62s 234ms/step - loss: 0.4508 - accuracy: 0.8609 - val_loss: 1.3268 - val_accuracy: 0.7168
#
# Epoch 00017: val_accuracy improved from 0.70933 to 0.71683, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 18/50
# 266/266 [==============================] - 62s 234ms/step - loss: 0.4312 - accuracy: 0.8642 - val_loss: 1.4032 - val_accuracy: 0.7098
#
# Epoch 00018: val_accuracy did not improve from 0.71683
# Epoch 19/50
# 266/266 [==============================] - 62s 234ms/step - loss: 0.4169 - accuracy: 0.8681 - val_loss: 1.4542 - val_accuracy: 0.6990
#
# Epoch 00019: val_accuracy did not improve from 0.71683
# Epoch 20/50
# 266/266 [==============================] - 62s 234ms/step - loss: 0.3793 - accuracy: 0.8804 - val_loss: 1.4338 - val_accuracy: 0.7009
#
# Epoch 00020: val_accuracy did not improve from 0.71683
# Epoch 21/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.3735 - accuracy: 0.8831 - val_loss: 1.3353 - val_accuracy: 0.7196
#
# Epoch 00021: val_accuracy improved from 0.71683 to 0.71964, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 22/50
# 266/266 [==============================] - 62s 234ms/step - loss: 0.3554 - accuracy: 0.8875 - val_loss: 1.4553 - val_accuracy: 0.7206
#
# Epoch 00022: val_accuracy improved from 0.71964 to 0.72058, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 23/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.3269 - accuracy: 0.8940 - val_loss: 1.3702 - val_accuracy: 0.7215
#
# Epoch 00023: val_accuracy improved from 0.72058 to 0.72152, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 24/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.3199 - accuracy: 0.8986 - val_loss: 1.4579 - val_accuracy: 0.7173
#
# Epoch 00024: val_accuracy did not improve from 0.72152
# Epoch 25/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.3003 - accuracy: 0.9029 - val_loss: 1.4419 - val_accuracy: 0.7361
#
# Epoch 00025: val_accuracy improved from 0.72152 to 0.73605, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 26/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2829 - accuracy: 0.9094 - val_loss: 1.4921 - val_accuracy: 0.7079
#
# Epoch 00026: val_accuracy did not improve from 0.73605
# Epoch 27/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.3112 - accuracy: 0.8986 - val_loss: 1.4416 - val_accuracy: 0.7229
#
# Epoch 00027: val_accuracy did not improve from 0.73605
# Epoch 28/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2652 - accuracy: 0.9147 - val_loss: 1.5804 - val_accuracy: 0.7070
#
# Epoch 00028: val_accuracy did not improve from 0.73605
# Epoch 29/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2756 - accuracy: 0.9100 - val_loss: 1.4215 - val_accuracy: 0.7150
#
# Epoch 00029: val_accuracy did not improve from 0.73605
# Epoch 30/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2657 - accuracy: 0.9155 - val_loss: 1.4764 - val_accuracy: 0.7271
#
# Epoch 00030: val_accuracy did not improve from 0.73605
# Epoch 31/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2591 - accuracy: 0.9184 - val_loss: 1.4824 - val_accuracy: 0.7182
#
# Epoch 00031: val_accuracy did not improve from 0.73605
# Epoch 32/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2342 - accuracy: 0.9265 - val_loss: 1.3827 - val_accuracy: 0.7211
#
# Epoch 00032: val_accuracy did not improve from 0.73605
# Epoch 33/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2292 - accuracy: 0.9261 - val_loss: 1.4563 - val_accuracy: 0.7211
#
# Epoch 00033: val_accuracy did not improve from 0.73605
# Epoch 34/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2316 - accuracy: 0.9232 - val_loss: 1.4876 - val_accuracy: 0.7220
#
# Epoch 00034: val_accuracy did not improve from 0.73605
# Epoch 35/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2359 - accuracy: 0.9248 - val_loss: 1.4724 - val_accuracy: 0.7323
#
# Epoch 00035: val_accuracy did not improve from 0.73605
# Epoch 36/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2142 - accuracy: 0.9311 - val_loss: 1.4829 - val_accuracy: 0.7168
#
# Epoch 00036: val_accuracy did not improve from 0.73605
# Epoch 37/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2143 - accuracy: 0.9298 - val_loss: 1.4277 - val_accuracy: 0.7290
#
# Epoch 00037: val_accuracy did not improve from 0.73605
# Epoch 38/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2054 - accuracy: 0.9333 - val_loss: 1.5302 - val_accuracy: 0.7225
#
# Epoch 00038: val_accuracy did not improve from 0.73605
# Epoch 39/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2035 - accuracy: 0.9322 - val_loss: 1.5185 - val_accuracy: 0.7271
#
# Epoch 00039: val_accuracy did not improve from 0.73605
# Epoch 40/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2006 - accuracy: 0.9331 - val_loss: 1.6079 - val_accuracy: 0.7135
#
# Epoch 00040: val_accuracy did not improve from 0.73605
# Epoch 41/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1827 - accuracy: 0.9399 - val_loss: 1.6167 - val_accuracy: 0.7168
#
# Epoch 00041: val_accuracy did not improve from 0.73605
# Epoch 42/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1990 - accuracy: 0.9358 - val_loss: 1.4541 - val_accuracy: 0.7379
#
# Epoch 00042: val_accuracy improved from 0.73605 to 0.73793, saving model to /root/userspace/private/competition/best_model_2.hdf5
# Epoch 43/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1908 - accuracy: 0.9372 - val_loss: 1.4769 - val_accuracy: 0.7286
#
# Epoch 00043: val_accuracy did not improve from 0.73793
# Epoch 44/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1954 - accuracy: 0.9379 - val_loss: 1.5669 - val_accuracy: 0.7192
#
# Epoch 00044: val_accuracy did not improve from 0.73793
# Epoch 45/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1696 - accuracy: 0.9439 - val_loss: 1.5048 - val_accuracy: 0.7375
#
# Epoch 00045: val_accuracy did not improve from 0.73793
# Epoch 46/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1807 - accuracy: 0.9416 - val_loss: 1.4484 - val_accuracy: 0.7379
#
# Epoch 00046: val_accuracy did not improve from 0.73793
# Epoch 47/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1591 - accuracy: 0.9468 - val_loss: 1.5091 - val_accuracy: 0.7356
#
# Epoch 00047: val_accuracy did not improve from 0.73793
# Epoch 48/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1839 - accuracy: 0.9390 - val_loss: 1.5988 - val_accuracy: 0.7248
#
# Epoch 00048: val_accuracy did not improve from 0.73793
# Epoch 49/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1732 - accuracy: 0.9417 - val_loss: 1.5327 - val_accuracy: 0.7267
#
# Epoch 00049: val_accuracy did not improve from 0.73793
# Epoch 50/50
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1643 - accuracy: 0.9451 - val_loss: 1.5753 - val_accuracy: 0.7323
#
# Epoch 00050: val_accuracy did not improve from 0.73793
# Test loss: 1.5752509628390685
# Test accuracy: 0.7323019504547119

# %%
# Plot learning curves
fig = plt.figure(figsize = (17, 4))
    
plt.subplot(121)
plt.plot(history.history['accuracy'], label = 'acc')
plt.plot(history.history['val_accuracy'], label = 'val_acc')
#plt.plot(history.history['acc'], label = 'acc')
#plt.plot(history.history['val_acc'], label = 'val_acc')
plt.legend()
plt.grid()
plt.title(f'accuracy')

plt.subplot(122)
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.legend()
plt.grid()
plt.title(f'loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
# Loading weights from best model
#model.load_weights('../working/best_model.hdf5')
model.load_weights('/root/userspace/private/competition/best_model_2.hdf5')

# Saving all model
#model.save('../working/model.hdf5')
model.save('/root/userspace/private/competition/model_2.hdf5')

# %%
mewtwo = ['https://cdn.bulbagarden.net/upload/thumb/7/78/150Mewtwo.png/250px-150Mewtwo.png',
         'https://cdn.vox-cdn.com/thumbor/sZPPvUyKyF97UEU-nNtVnC3LpF8=/0x0:1750x941/1200x800/filters:focal(878x316:1158x596)/cdn.vox-cdn.com/uploads/chorus_image/image/63823444/original.0.jpg',
         'https://images-na.ssl-images-amazon.com/images/I/61j5ozFjJ0L._SL1024_.jpg']

pikachu = ['https://lh3.googleusercontent.com/proxy/DrjDlKlu9YonKbj3iNCJNJ3DGqzy9GjeXXSUv-TcVV4UN9PMCAM5yIkGLPG7wYo3UeA4sq5OmUWM8M6K5hy2KOAhf8SOL3zPH3axb2Xo3HX2XTU8M2xW4X6lVg=w720-h405-rw',
          'https://giantbomb1.cbsistatic.com/uploads/scale_medium/0/6087/2437349-pikachu.png',
          'https://johnlewis.scene7.com/is/image/JohnLewis/237525467']

charmander = ['https://img.pokemondb.net/artwork/large/charmander.jpg',
             'https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P5073/701-03990/P5073_701-03990_01.jpg',
             'https://static.posters.cz/image/750/%D0%A7%D0%B0%D1%88%D0%BA%D0%B0/pokemon-charmander-glow-i72513.jpg']

bulbasaur = ['https://img.pokemondb.net/artwork/large/bulbasaur.jpg',
            'https://ae01.alicdn.com/kf/HTB1aWullxSYBuNjSsphq6zGvVXaR/Big-Size-55-CM-Plush-Toy-Squirtle-Bulbasaur-Charmander-Toy-Sleeping-Pillow-Doll-For-Kid-Birthday.jpg',
            'https://cdn.bulbagarden.net/upload/thumb/f/f7/Bulbasaur_Detective_Pikachu.jpg/250px-Bulbasaur_Detective_Pikachu.jpg']

squirtle = ['https://assets.pokemon.com/assets/cms2/img/pokedex/full/007.png',
           'https://cdn.vox-cdn.com/thumbor/l4cKX7ZWargjs-zlxOSW2WZVgfI=/0x0:2040x1360/1200x800/filters:focal(857x517:1183x843)/cdn.vox-cdn.com/uploads/chorus_image/image/61498573/jbareham_180925_ply0802_0030.1537570476.jpg',
           'https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fblogs-images.forbes.com%2Fdavidthier%2Ffiles%2F2018%2F07%2FSquirtle_Squad.jpg']

test_df = [mewtwo, pikachu, charmander, bulbasaur, squirtle]

# %%
# Lists to store our future data
val_x = []
val_y = []

for i, urls in enumerate(test_df):
    for url in urls:        
        r = requests.get(url, stream = True).raw
        image = np.asarray(bytearray(r.read()), dtype="uint8")
        image = cv.imdecode(image, cv.IMREAD_COLOR)
        val_x.append(image)
        val_y.append(i)

# plt.imshow(image[:, :, ::-1])

# %%
rows = 5
cols = 3

fig = plt.figure(figsize = (25, 25))

for i, j in enumerate(zip(val_x, val_y)): # i - for subplots
    orig = j[0] # Original, not resized image
    label = j[1] # Label for that image
    
    #image = cv.resize(orig, (96, 96)) # Resizing image to (96, 96)
    #image = image.reshape(-1, 96, 96, 3) / 255.0 # Reshape and scale resized image
    image = cv.resize(orig, (128, 128)) # Resizing image to (96, 96)
    image = image.reshape(-1, 128, 128, 3) / 255.0 # Reshape and scale resized image
    preds = model.predict(image) # Predicting image
    pred_class = np.argmax(preds) # Defining predicted class
    
    true_label = f'True class: {imbalanced[label]}'
    pred_label = f'Predicted: {imbalanced[pred_class]} {round(preds[0][pred_class] * 100, 2)}%'
    
    fig.add_subplot(rows, cols, i+1)
    plt.imshow(orig[:, :, ::-1])
    plt.title(f'{true_label}\n{pred_label}')
    plt.axis('off')
    
plt.tight_layout()
