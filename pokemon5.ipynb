# %%
# Importing all necessary libraries
import numpy as np
import pandas as pd
import cv2 as cv # pip install opencv-python
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import gc
import requests

from PIL import Image
from io import BytesIO

from collections import Counter
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense, Input
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
#from keras.applications.resnet50 import ResNet50
#from keras.applications.xception import Xception
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers.pooling import GlobalAveragePooling2D

warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
# A little bit of data exploration
path = '/root/userspace/private/competition/dataset' # Path to directory which contains classes
classes = os.listdir(path) # List of all classes
print(f'Total number of categories: {len(classes)}')

# A dictionary which contains class and number of images in that class
counts = {}
for c in classes:
    counts[c] = len(os.listdir(os.path.join(path, c)))
    
print(f'Total number of images in dataset: {sum(list(counts.values()))}')

# Number of images in each clsss plot
fig = plt.figure(figsize = (25, 5))
sns.lineplot(x = list(counts.keys()), y = list(counts.values())).set_title('Number of images in each class')
plt.xticks(rotation = 90)
plt.margins(x=0)
plt.show()
# Out:
# Total number of categories: 149
# Total number of images in dataset: 10693

# %%
# Sort our "counts" dictionary and selecting 5 classes with most number of images
#imbalanced = sorted(counts.items(), key = lambda x: x[1], reverse = True)[:5]
imbalanced = sorted(counts.items(), key = lambda x: x[1], reverse = True)[:150]
print(imbalanced)

# Taking only labels, it will come in handy in future
imbalanced = [i[0] for i in imbalanced]
print(imbalanced)
# Out:
# [('Mewtwo', 307), ('Pikachu', 298), ('Charmander', 296), ('Bulbasaur', 289), ('Squirtle', 280), ('Psyduck', 159), ('Spearow', 130), ('Fearow', 124), ('Dratini', 109), ('Aerodactyl', 97), ('Rapidash', 83), ('Shellder', 81), ('Pidgey', 74), ('Ninetales', 74), ('Mankey', 72), ('Machamp', 72), ('Raichu', 71), ('Sandslash', 71), ('Muk', 71), ('Lapras', 71), ('Meowth', 70), ('Marowak', 70), ('Exeggutor', 70), ('Raticate', 70), ('Primeape', 70), ('Kingler', 69), ('Rhyhorn', 69), ('Growlithe', 69), ('Snorlax', 69), ('Vulpix', 68), ('Scyther', 68), ('Gyarados', 68), ('Vaporeon', 68), ('Nidoking', 68), ('Seadra', 67), ('Wigglytuff', 67), ('Lickitung', 67), ('Tauros', 67), ('Rattata', 67), ('Mew', 67), ('Golbat', 67), ('Vileplume', 67), ('Dewgong', 67), ('Kakuna', 67), ('Electrode', 67), ('Venomoth', 66), ('Nidoqueen', 66), ('Butterfree', 66), ('Pidgeot', 66), ('Venusaur', 66), ('Kabutops', 66), ('Oddish', 66), ('Ponyta', 66), ('Sandshrew', 66), ('Voltorb', 65), ('Koffing', 65), ('Seaking', 65), ('Metapod', 65), ('Charmeleon', 65), ('Dodrio', 65), ('Hitmonlee', 65), ('Poliwag', 65), ('Jigglypuff', 65), ('Dragonair', 65), ('Golem', 64), ('Poliwhirl', 64), ('Grimer', 64), ('Dugtrio', 64), ('Onix', 64), ('Jolteon', 64), ('Krabby', 64), ('Farfetchd', 64), ('Slowbro', 63), ('Tangela', 63), ('Nidorino', 63), ('Horsea', 63), ('Poliwrath', 63), ('Hypno', 63), ('Weezing', 63), ('Pinsir', 63), ('Kangaskhan', 63), ('Haunter', 63), ('Pidgeotto', 63), ('Arbok', 63), ('Moltres', 62), ('Blastoise', 62), ('Dragonite', 62), ('Wartortle', 61), ('Kadabra', 61), ('Arcanine', 61), ('Seel', 61), ('Golduck', 61), ('Hitmonchan', 61), ('Drowzee', 60), ('Staryu', 60), ('Slowpoke', 60), ('Gengar', 60), ('Zapdos', 60), ('Cloyster', 60), ('Magnemite', 60), ('Clefairy', 60), ('Nidorina', 59), ('Rhydon', 59), ('Cubone', 59), ('Magikarp', 59), ('Weedle', 59), ('Jynx', 59), ('Magneton', 59), ('Starmie', 59), ('Magmar', 59), ('MrMime', 59), ('Flareon', 59), ('Graveler', 58), ('Gloom', 58), ('Goldeen', 58), ('Chansey', 58), ('Omastar', 58), ('Persian', 57), ('Exeggcute', 57), ('Tentacool', 57), ('Venonat', 57), ('Tentacruel', 57), ('Kabuto', 56), ('Articuno', 56), ('Geodude', 56), ('Bellsprout', 55), ('Porygon', 55), ('Victreebel', 55), ('Omanyte', 55), ('Paras', 55), ('Electabuzz', 54), ('Machop', 53), ('Parasect', 53), ('Beedrill', 53), ('Ivysaur', 53), ('Charizard', 52), ('Ekans', 52), ('Machoke', 51), ('Diglett', 51), ('Weepinbell', 51), ('Gastly', 50), ('Caterpie', 50), ('Ditto', 49), ('Alakazam', 49), ('Zubat', 49), ('Clefable', 49), ('Doduo', 48), ('Abra', 42), ('Eevee', 41)]
# ['Mewtwo', 'Pikachu', 'Charmander', 'Bulbasaur', 'Squirtle', 'Psyduck', 'Spearow', 'Fearow', 'Dratini', 'Aerodactyl', 'Rapidash', 'Shellder', 'Pidgey', 'Ninetales', 'Mankey', 'Machamp', 'Raichu', 'Sandslash', 'Muk', 'Lapras', 'Meowth', 'Marowak', 'Exeggutor', 'Raticate', 'Primeape', 'Kingler', 'Rhyhorn', 'Growlithe', 'Snorlax', 'Vulpix', 'Scyther', 'Gyarados', 'Vaporeon', 'Nidoking', 'Seadra', 'Wigglytuff', 'Lickitung', 'Tauros', 'Rattata', 'Mew', 'Golbat', 'Vileplume', 'Dewgong', 'Kakuna', 'Electrode', 'Venomoth', 'Nidoqueen', 'Butterfree', 'Pidgeot', 'Venusaur', 'Kabutops', 'Oddish', 'Ponyta', 'Sandshrew', 'Voltorb', 'Koffing', 'Seaking', 'Metapod', 'Charmeleon', 'Dodrio', 'Hitmonlee', 'Poliwag', 'Jigglypuff', 'Dragonair', 'Golem', 'Poliwhirl', 'Grimer', 'Dugtrio', 'Onix', 'Jolteon', 'Krabby', 'Farfetchd', 'Slowbro', 'Tangela', 'Nidorino', 'Horsea', 'Poliwrath', 'Hypno', 'Weezing', 'Pinsir', 'Kangaskhan', 'Haunter', 'Pidgeotto', 'Arbok', 'Moltres', 'Blastoise', 'Dragonite', 'Wartortle', 'Kadabra', 'Arcanine', 'Seel', 'Golduck', 'Hitmonchan', 'Drowzee', 'Staryu', 'Slowpoke', 'Gengar', 'Zapdos', 'Cloyster', 'Magnemite', 'Clefairy', 'Nidorina', 'Rhydon', 'Cubone', 'Magikarp', 'Weedle', 'Jynx', 'Magneton', 'Starmie', 'Magmar', 'MrMime', 'Flareon', 'Graveler', 'Gloom', 'Goldeen', 'Chansey', 'Omastar', 'Persian', 'Exeggcute', 'Tentacool', 'Venonat', 'Tentacruel', 'Kabuto', 'Articuno', 'Geodude', 'Bellsprout', 'Porygon', 'Victreebel', 'Omanyte', 'Paras', 'Electabuzz', 'Machop', 'Parasect', 'Beedrill', 'Ivysaur', 'Charizard', 'Ekans', 'Machoke', 'Diglett', 'Weepinbell', 'Gastly', 'Caterpie', 'Ditto', 'Alakazam', 'Zubat', 'Clefable', 'Doduo', 'Abra', 'Eevee']

# %%
X = [] # List for images
Y = [] # List for labels

# Loop through all classes
for c in classes:
    # We take only classes that we defined in 'imbalanced' list
    if c in imbalanced:
        dir_path = os.path.join(path, c)
        label = imbalanced.index(c) # Our label is an index of class in 'imbalanced' list
        
        # Reading, resizing and adding image and label to lists
        for i in os.listdir(dir_path):
            image = cv.imread(os.path.join(dir_path, i))
            
            try:
                #resized = cv.resize(image, (96, 96)) # Resizing images to (96, 96)
                resized = cv.resize(image, (196, 196)) # Resizing images to (196, 196)
                X.append(resized)
                Y.append(label)
            
            # If we can't read image - we skip it
            except:
                print(os.path.join(dir_path, i), '[ERROR] can\'t read the file')
                continue       
            
print('DONE')
# Out:
# /root/userspace/private/competition/dataset/Venomoth/bb5d47bced6e4e33a77faa17e1eec906.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Nidoqueen/89a9c05292d84aeab91bb105da37e0c0.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Voltorb/94f443d834f94c1e8e6b088d879646d4.gif~c200 [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Graveler/3fe3c6a0bbd14de89092d2c675f743c1.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Fearow/8f2d7986ab76482fb76cac6a91b66de4.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Fearow/2c8d5221e92444f2b9477350e405bc54.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Kingler/a87633dcbf9643319da5d702e2e1a56c.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Scyther/a8734f10941a4deb95fcf7388e4fe8e2.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Exeggutor/f29b4f9fccff4055b167ece6556143cd.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Exeggutor/2b8bc491c5ca4e788999f8ea53617638.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Gyarados/6444e4ec716b44a4959bf97c1e75a935.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Hypno/ea34a7f7c68c467e8bf7240b26e0002c.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Zapdos/c99b2d19544c4cbbacd7711ade660279.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Golduck/bc08a691e7cb41b0bec2adf931dc9634.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Magneton/45e434d002bd44eeb1acbc2decc8ee0f.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Electabuzz/28a02c7a1389471693ff89712f1064f3.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Kabutops/01b54e83745340569cdde1442c8c429f.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Growlithe/f7a87c057dc94a32a0d5aedd1abed088.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Cloyster/ff270ebfab0f46b3b05c3fecd6a15ef9.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Caterpie/dcd36168d2bd470aaca333fb3bdf6bfa.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Poliwag/456c5063598a46a68a60ebcde5647ace.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Mewtwo/ed9eb0e7d3494c6992e06196f5b7cc05.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Venonat/56425d5f66e64584afbfc797b93c7ee5.ico [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Dewgong/e3ecbb47e192470aa8686734b7813b43.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Omastar/1be6e7da1bba4379b298b20013c57b4b.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Omastar/59761964ea084b4c85fc97837cd60fd8.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Machamp/546d68ace3ac414eb671b0e87880d683.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Tentacruel/d6fb0a3046364ea2b49525c6f6b966e5.svg [ERROR] can't read the file
# DONE

# %%
# Counting appearances of each label in labels list
obj = Counter(Y)

# Plotting number of images in each class
fig = plt.figure(figsize = (20, 5))
sns.barplot(x = [imbalanced[i] for i in obj.keys()], y = list(obj.values())).set_title('Number of images in each class')
plt.margins(x=0)
plt.show()

# %%
# Convert list with images to numpy array and reshape it 
#X = np.array(X).reshape(-1, 96, 96, 3)
X = np.array(X).reshape(-1, 196, 196, 3)

# Scaling data in array
X = X / 255.0

# Convert labels to categorical format
y = to_categorical(Y, num_classes = len(imbalanced))

# Splitting data to train and test datasets
# I'll use these datasets only for training, for final predictions I'll use random pictures from internet
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, shuffle = True, random_state = 666)

# %%
# Defining ImageDataGenerator Iinstance
#datagen = ImageDataGenerator(rotation_range = 45, # Degree range for random rotations
#                            zoom_range = 0.2, # Range for random zoom 
#                            horizontal_flip = True, # Randomly flip inputs horizontally
#                            width_shift_range = 0.15, # Range for horizontal shift 
#                            height_shift_range = 0.15, # Range for vertical shift 
#                            shear_range = 0.2) # Shear Intensity
datagen = ImageDataGenerator(
                            #featurewise_center = True, 
                            #featurewise_std_normalization = True,
                            rotation_range = 45, # Degree range for random rotations
                            zoom_range = 0.5, # Range for random zoom 
                            horizontal_flip = True, # Randomly flip inputs horizontally
                            width_shift_range = 0.5, # Range for horizontal shift 
                            height_shift_range = 0.5, # Range for vertical shift 
                            shear_range = 0.2) # Shear Intensity

datagen.fit(X_train)

# This piece of code can be used if you eant to look what your datagen doing with your images
# img = X[600]
# img = img.reshape([-1, 96, 96, 3])

# i = 0
# fig = plt.figure(figsize = (18, 8))

# for i, flow in enumerate(datagen.flow(img, batch_size = 1)):
#     fig.add_subplot(2, 5, i+1)
#     plt.imshow(np.squeeze(flow[:, :, ::-1]))
#     plt.axis('off')
#     i += 1
#     if i >= 10:
#         break

# %%
#model = Sequential()
#model.add(Conv2D(32, 3, padding = 'same', activation = 'relu', input_shape =(96, 96, 3), kernel_initializer = 'he_normal'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(128, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(128, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(256, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(256, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Flatten())
#model.add(Dense(512, activation = 'relu'))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))
#model.add(Dense(256, activation = 'relu'))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))
#model.add(Dense(len(imbalanced), activation = 'softmax'))
#
#model.summary()
#
##checkpoint = ModelCheckpoint('../working/best_model.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#checkpoint = ModelCheckpoint('/Users/nakayama/Desktop/lesson/advanced/work/pokemon/best_model.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#
#model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
##history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 100, validation_data = [X_test, y_test],
##                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])
#history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 10, validation_data = [X_test, y_test],
#                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])

#input_tensor = Input(shape=(96, 96, 3))
input_tensor = Input(shape=(196, 196, 3))
#base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=input_tensor)
#base_model = Xception(include_top=False, weights='imagenet', input_tensor=input_tensor)
base_model = MobileNetV2(include_top=False, weights='imagenet', input_tensor=input_tensor)

# 全結合層の新規構築
top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
top_model = Dense(1024, activation = 'relu')(top_model)
predictions = Dense(len(imbalanced), activation = 'softmax')(top_model)

# ネットワーク定義
model = Model(inputs = base_model.input, outputs = predictions)

print("{}層".format(len(model.layers)))

# block_16_expand 層の手前まで freeze
trainable = False
for layer in model.layers:
    if layer.name == 'block_16_expand':
        trainable = True
    
    # block_16_expand 以降の層は freeze 解除
    layer.trainable = trainable

    # Batch Normalization の freeze 解除
    if layer.name.startswith('bn_'):
        layer.trainable = True
    if layer.name.endswith('_BN'):
        layer.trainable = True

model.summary()

checkpoint = ModelCheckpoint('/root/userspace/private/competition/best_model_5.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#checkpoint = ModelCheckpoint('/root/userspace/private/competition/best_model.hdf5', verbose = 1, monitor = 'val_acc', save_best_only = True)

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# 158層
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 196, 196, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 197, 197, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 98, 98, 32)   864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 98, 98, 32)   128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 98, 98, 32)   0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 98, 98, 32)   288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 98, 98, 32)   128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 98, 98, 32)   0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 98, 98, 16)   512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 98, 98, 16)   64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 98, 98, 96)   1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 98, 98, 96)   384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 98, 98, 96)   0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 99, 99, 96)   0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 49, 49, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 49, 49, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 49, 49, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 49, 49, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 49, 49, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 49, 49, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 49, 49, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 49, 49, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 49, 49, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 49, 49, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 49, 49, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 49, 49, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 49, 49, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 49, 49, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 49, 49, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 49, 49, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 49, 49, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 51, 51, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 25, 25, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 25, 25, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 25, 25, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 25, 25, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 25, 25, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 25, 25, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 25, 25, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 25, 25, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 25, 25, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 25, 25, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 25, 25, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 25, 25, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 25, 25, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 25, 25, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 25, 25, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 25, 25, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 25, 25, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 25, 25, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 25, 25, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 25, 25, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 25, 25, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 25, 25, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 25, 25, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 25, 25, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 25, 25, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 25, 25, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 27, 27, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 13, 13, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 13, 13, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 13, 13, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 13, 13, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 13, 13, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 13, 13, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 13, 13, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 13, 13, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 13, 13, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 13, 13, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 13, 13, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 13, 13, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 13, 13, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 13, 13, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 13, 13, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 13, 13, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 13, 13, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 13, 13, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 13, 13, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 13, 13, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 13, 13, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 13, 13, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 13, 13, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 13, 13, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 13, 13, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 13, 13, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 13, 13, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 13, 13, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 13, 13, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 13, 13, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 13, 13, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 13, 13, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 13, 13, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 13, 13, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 13, 13, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 13, 13, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 13, 13, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 13, 13, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 13, 13, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 13, 13, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 13, 13, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 13, 13, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 13, 13, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 13, 13, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 13, 13, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 13, 13, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 13, 13, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 13, 13, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 13, 13, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 13, 13, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 13, 13, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 13, 13, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 13, 13, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 13, 13, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 13, 13, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 13, 13, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 13, 13, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 13, 13, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 13, 13, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 13, 13, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 13, 13, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         1311744     global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 149)          152725      dense_3[0][0]
# ==================================================================================================
# Total params: 3,722,453
# Trainable params: 2,377,621
# Non-trainable params: 1,344,832
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 30, validation_data = [X_test, y_test],
                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])

# 性能評価
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 266/266 [==============================] - 118s 444ms/step - loss: 4.1850 - accuracy: 0.1406 - val_loss: 7.3106 - val_accuracy: 0.1627
#
# Epoch 00001: val_accuracy improved from -inf to 0.16268, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 2/30
# 266/266 [==============================] - 78s 295ms/step - loss: 3.0773 - accuracy: 0.2894 - val_loss: 8.0173 - val_accuracy: 0.2016
#
# Epoch 00002: val_accuracy improved from 0.16268 to 0.20159, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 3/30
# 266/266 [==============================] - 79s 299ms/step - loss: 2.6162 - accuracy: 0.3614 - val_loss: 5.4572 - val_accuracy: 0.3160
#
# Epoch 00003: val_accuracy improved from 0.20159 to 0.31599, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 4/30
# 266/266 [==============================] - 80s 299ms/step - loss: 2.3059 - accuracy: 0.4315 - val_loss: 5.5086 - val_accuracy: 0.3291
#
# Epoch 00004: val_accuracy improved from 0.31599 to 0.32911, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 5/30
# 266/266 [==============================] - 79s 299ms/step - loss: 2.0751 - accuracy: 0.4780 - val_loss: 4.5746 - val_accuracy: 0.4008
#
# Epoch 00005: val_accuracy improved from 0.32911 to 0.40084, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 6/30
# 266/266 [==============================] - 79s 298ms/step - loss: 1.9199 - accuracy: 0.5186 - val_loss: 4.8922 - val_accuracy: 0.3919
#
# Epoch 00006: val_accuracy did not improve from 0.40084
# Epoch 7/30
# 266/266 [==============================] - 80s 300ms/step - loss: 1.7892 - accuracy: 0.5422 - val_loss: 3.5102 - val_accuracy: 0.4801
#
# Epoch 00007: val_accuracy improved from 0.40084 to 0.48008, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 8/30
# 266/266 [==============================] - 78s 295ms/step - loss: 1.7177 - accuracy: 0.5596 - val_loss: 3.2500 - val_accuracy: 0.5120
#
# Epoch 00008: val_accuracy improved from 0.48008 to 0.51195, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 9/30
# 266/266 [==============================] - 80s 301ms/step - loss: 1.6174 - accuracy: 0.5744 - val_loss: 2.4945 - val_accuracy: 0.5785
#
# Epoch 00009: val_accuracy improved from 0.51195 to 0.57853, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 10/30
# 266/266 [==============================] - 80s 299ms/step - loss: 1.5332 - accuracy: 0.5979 - val_loss: 2.1609 - val_accuracy: 0.6067
#
# Epoch 00010: val_accuracy improved from 0.57853 to 0.60666, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 11/30
# 266/266 [==============================] - 78s 293ms/step - loss: 1.4862 - accuracy: 0.6124 - val_loss: 2.0996 - val_accuracy: 0.6104
#
# Epoch 00011: val_accuracy improved from 0.60666 to 0.61041, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 12/30
# 266/266 [==============================] - 78s 295ms/step - loss: 1.4193 - accuracy: 0.6207 - val_loss: 2.0910 - val_accuracy: 0.6259
#
# Epoch 00012: val_accuracy improved from 0.61041 to 0.62588, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 13/30
# 266/266 [==============================] - 78s 295ms/step - loss: 1.4235 - accuracy: 0.6280 - val_loss: 2.1074 - val_accuracy: 0.6287
#
# Epoch 00013: val_accuracy improved from 0.62588 to 0.62869, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 14/30
# 266/266 [==============================] - 79s 297ms/step - loss: 1.3236 - accuracy: 0.6452 - val_loss: 1.7987 - val_accuracy: 0.6714
#
# Epoch 00014: val_accuracy improved from 0.62869 to 0.67135, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 15/30
# 266/266 [==============================] - 79s 295ms/step - loss: 1.2855 - accuracy: 0.6573 - val_loss: 1.5087 - val_accuracy: 0.7070
#
# Epoch 00015: val_accuracy improved from 0.67135 to 0.70699, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 16/30
# 266/266 [==============================] - 78s 294ms/step - loss: 1.2448 - accuracy: 0.6684 - val_loss: 1.8093 - val_accuracy: 0.6620
#
# Epoch 00016: val_accuracy did not improve from 0.70699
# Epoch 17/30
# 266/266 [==============================] - 78s 293ms/step - loss: 1.2245 - accuracy: 0.6659 - val_loss: 1.5817 - val_accuracy: 0.7028
#
# Epoch 00017: val_accuracy did not improve from 0.70699
# Epoch 18/30
# 266/266 [==============================] - 79s 297ms/step - loss: 1.1925 - accuracy: 0.6796 - val_loss: 1.4267 - val_accuracy: 0.7196
#
# Epoch 00018: val_accuracy improved from 0.70699 to 0.71964, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 19/30
# 266/266 [==============================] - 78s 294ms/step - loss: 1.1318 - accuracy: 0.6907 - val_loss: 1.7496 - val_accuracy: 0.6892
#
# Epoch 00019: val_accuracy did not improve from 0.71964
# Epoch 20/30
# 266/266 [==============================] - 78s 293ms/step - loss: 1.1381 - accuracy: 0.6953 - val_loss: 1.6872 - val_accuracy: 0.6817
#
# Epoch 00020: val_accuracy did not improve from 0.71964
# Epoch 21/30
# 266/266 [==============================] - 77s 291ms/step - loss: 1.0914 - accuracy: 0.7036 - val_loss: 1.4394 - val_accuracy: 0.7215
#
# Epoch 00021: val_accuracy improved from 0.71964 to 0.72152, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 22/30
# 266/266 [==============================] - 77s 291ms/step - loss: 1.0854 - accuracy: 0.7028 - val_loss: 1.4208 - val_accuracy: 0.7215
#
# Epoch 00022: val_accuracy did not improve from 0.72152
# Epoch 23/30
# 266/266 [==============================] - 77s 291ms/step - loss: 1.0450 - accuracy: 0.7072 - val_loss: 1.3904 - val_accuracy: 0.7276
#
# Epoch 00023: val_accuracy improved from 0.72152 to 0.72761, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 24/30
# 266/266 [==============================] - 77s 290ms/step - loss: 1.0473 - accuracy: 0.7188 - val_loss: 1.5098 - val_accuracy: 0.7093
#
# Epoch 00024: val_accuracy did not improve from 0.72761
# Epoch 25/30
# 266/266 [==============================] - 77s 290ms/step - loss: 1.0065 - accuracy: 0.7227 - val_loss: 1.5012 - val_accuracy: 0.7037
#
# Epoch 00025: val_accuracy did not improve from 0.72761
# Epoch 26/30
# 266/266 [==============================] - 77s 290ms/step - loss: 0.9843 - accuracy: 0.7254 - val_loss: 1.3833 - val_accuracy: 0.7281
#
# Epoch 00026: val_accuracy improved from 0.72761 to 0.72808, saving model to /root/userspace/private/competition/best_model_5.hdf5
# Epoch 27/30
# 266/266 [==============================] - 77s 291ms/step - loss: 0.9417 - accuracy: 0.7355 - val_loss: 1.5265 - val_accuracy: 0.7112
#
# Epoch 00027: val_accuracy did not improve from 0.72808
# Epoch 28/30
# 266/266 [==============================] - 77s 290ms/step - loss: 0.9117 - accuracy: 0.7446 - val_loss: 1.5880 - val_accuracy: 0.7276
#
# Epoch 00028: val_accuracy did not improve from 0.72808
# Epoch 29/30
# 266/266 [==============================] - 77s 289ms/step - loss: 0.9191 - accuracy: 0.7480 - val_loss: 1.5738 - val_accuracy: 0.7140
#
# Epoch 00029: val_accuracy did not improve from 0.72808
# Epoch 30/30
# 266/266 [==============================] - 77s 290ms/step - loss: 0.9172 - accuracy: 0.7452 - val_loss: 1.7277 - val_accuracy: 0.6868
#
# Epoch 00030: val_accuracy did not improve from 0.72808
# Test loss: 1.7277277581187631
# Test accuracy: 0.6868260502815247

# %%
# Plot learning curves
fig = plt.figure(figsize = (17, 4))
    
plt.subplot(121)
plt.plot(history.history['accuracy'], label = 'acc')
plt.plot(history.history['val_accuracy'], label = 'val_acc')
#plt.plot(history.history['acc'], label = 'acc')
#plt.plot(history.history['val_acc'], label = 'val_acc')
plt.legend()
plt.grid()
plt.title(f'accuracy')

plt.subplot(122)
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.legend()
plt.grid()
plt.title(f'loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
# Loading weights from best model
#model.load_weights('../working/best_model.hdf5')
model.load_weights('/root/userspace/private/competition/best_model_5.hdf5')

# Saving all model
#model.save('../working/model.hdf5')
model.save('/root/userspace/private/competition/model_5.hdf5')

# %%
mewtwo = ['https://cdn.bulbagarden.net/upload/thumb/7/78/150Mewtwo.png/250px-150Mewtwo.png',
         'https://cdn.vox-cdn.com/thumbor/sZPPvUyKyF97UEU-nNtVnC3LpF8=/0x0:1750x941/1200x800/filters:focal(878x316:1158x596)/cdn.vox-cdn.com/uploads/chorus_image/image/63823444/original.0.jpg',
         'https://images-na.ssl-images-amazon.com/images/I/61j5ozFjJ0L._SL1024_.jpg']

pikachu = ['https://lh3.googleusercontent.com/proxy/DrjDlKlu9YonKbj3iNCJNJ3DGqzy9GjeXXSUv-TcVV4UN9PMCAM5yIkGLPG7wYo3UeA4sq5OmUWM8M6K5hy2KOAhf8SOL3zPH3axb2Xo3HX2XTU8M2xW4X6lVg=w720-h405-rw',
          'https://giantbomb1.cbsistatic.com/uploads/scale_medium/0/6087/2437349-pikachu.png',
          'https://johnlewis.scene7.com/is/image/JohnLewis/237525467']

charmander = ['https://img.pokemondb.net/artwork/large/charmander.jpg',
             'https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P5073/701-03990/P5073_701-03990_01.jpg',
             'https://static.posters.cz/image/750/%D0%A7%D0%B0%D1%88%D0%BA%D0%B0/pokemon-charmander-glow-i72513.jpg']

bulbasaur = ['https://img.pokemondb.net/artwork/large/bulbasaur.jpg',
            'https://ae01.alicdn.com/kf/HTB1aWullxSYBuNjSsphq6zGvVXaR/Big-Size-55-CM-Plush-Toy-Squirtle-Bulbasaur-Charmander-Toy-Sleeping-Pillow-Doll-For-Kid-Birthday.jpg',
            'https://cdn.bulbagarden.net/upload/thumb/f/f7/Bulbasaur_Detective_Pikachu.jpg/250px-Bulbasaur_Detective_Pikachu.jpg']

squirtle = ['https://assets.pokemon.com/assets/cms2/img/pokedex/full/007.png',
           'https://cdn.vox-cdn.com/thumbor/l4cKX7ZWargjs-zlxOSW2WZVgfI=/0x0:2040x1360/1200x800/filters:focal(857x517:1183x843)/cdn.vox-cdn.com/uploads/chorus_image/image/61498573/jbareham_180925_ply0802_0030.1537570476.jpg',
           'https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fblogs-images.forbes.com%2Fdavidthier%2Ffiles%2F2018%2F07%2FSquirtle_Squad.jpg']

test_df = [mewtwo, pikachu, charmander, bulbasaur, squirtle]

# %%
# Lists to store our future data
val_x = []
val_y = []

for i, urls in enumerate(test_df):
    for url in urls:        
        r = requests.get(url, stream = True).raw
        image = np.asarray(bytearray(r.read()), dtype="uint8")
        image = cv.imdecode(image, cv.IMREAD_COLOR)
        val_x.append(image)
        val_y.append(i)

# plt.imshow(image[:, :, ::-1])

# %%
rows = 5
cols = 3

fig = plt.figure(figsize = (25, 25))

for i, j in enumerate(zip(val_x, val_y)): # i - for subplots
    orig = j[0] # Original, not resized image
    label = j[1] # Label for that image
    
    #image = cv.resize(orig, (96, 96)) # Resizing image to (96, 96)
    #image = image.reshape(-1, 96, 96, 3) / 255.0 # Reshape and scale resized image
    image = cv.resize(orig, (196, 196)) # Resizing image to (196, 196)
    image = image.reshape(-1, 196, 196, 3) / 255.0 # Reshape and scale resized image
    preds = model.predict(image) # Predicting image
    pred_class = np.argmax(preds) # Defining predicted class
    
    true_label = f'True class: {imbalanced[label]}'
    pred_label = f'Predicted: {imbalanced[pred_class]} {round(preds[0][pred_class] * 100, 2)}%'
    
    fig.add_subplot(rows, cols, i+1)
    plt.imshow(orig[:, :, ::-1])
    plt.title(f'{true_label}\n{pred_label}')
    plt.axis('off')
    
plt.tight_layout()
