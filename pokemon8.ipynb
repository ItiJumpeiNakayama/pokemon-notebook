# %%
# Importing all necessary libraries
import numpy as np
import pandas as pd
import cv2 as cv # pip install opencv-python
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import gc
import requests

from PIL import Image
from io import BytesIO

from collections import Counter
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense, Input
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
#from keras.applications.resnet50 import ResNet50
from keras.applications.xception import Xception
from keras.layers.pooling import GlobalAveragePooling2D

warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
# A little bit of data exploration
path = '/root/userspace/private/competition/dataset' # Path to directory which contains classes
classes = os.listdir(path) # List of all classes
print(f'Total number of categories: {len(classes)}')

# A dictionary which contains class and number of images in that class
counts = {}
for c in classes:
    counts[c] = len(os.listdir(os.path.join(path, c)))
    
print(f'Total number of images in dataset: {sum(list(counts.values()))}')

# Number of images in each clsss plot
fig = plt.figure(figsize = (25, 5))
sns.lineplot(x = list(counts.keys()), y = list(counts.values())).set_title('Number of images in each class')
plt.xticks(rotation = 90)
plt.margins(x=0)
plt.show()
# Out:
# Total number of categories: 149
# Total number of images in dataset: 10693

# %%
# Sort our "counts" dictionary and selecting 5 classes with most number of images
#imbalanced = sorted(counts.items(), key = lambda x: x[1], reverse = True)[:5]
#imbalanced = sorted(counts.items(), key = lambda x: x[1], reverse = True)[:150]
imbalanced = sorted(counts.items(), key = lambda x: x[0], reverse = False)[:149]
print(imbalanced)

# Taking only labels, it will come in handy in future
imbalanced = [i[0] for i in imbalanced]
print(imbalanced)
# Out:
# [('Abra', 42), ('Aerodactyl', 97), ('Alakazam', 49), ('Arbok', 63), ('Arcanine', 61), ('Articuno', 56), ('Beedrill', 53), ('Bellsprout', 55), ('Blastoise', 62), ('Bulbasaur', 289), ('Butterfree', 66), ('Caterpie', 50), ('Chansey', 58), ('Charizard', 52), ('Charmander', 296), ('Charmeleon', 65), ('Clefable', 49), ('Clefairy', 60), ('Cloyster', 60), ('Cubone', 59), ('Dewgong', 67), ('Diglett', 51), ('Ditto', 49), ('Dodrio', 65), ('Doduo', 48), ('Dragonair', 65), ('Dragonite', 62), ('Dratini', 109), ('Drowzee', 60), ('Dugtrio', 64), ('Eevee', 41), ('Ekans', 52), ('Electabuzz', 54), ('Electrode', 67), ('Exeggcute', 57), ('Exeggutor', 70), ('Farfetchd', 64), ('Fearow', 124), ('Flareon', 59), ('Gastly', 50), ('Gengar', 60), ('Geodude', 56), ('Gloom', 58), ('Golbat', 67), ('Goldeen', 58), ('Golduck', 61), ('Golem', 64), ('Graveler', 58), ('Grimer', 64), ('Growlithe', 69), ('Gyarados', 68), ('Haunter', 63), ('Hitmonchan', 61), ('Hitmonlee', 65), ('Horsea', 63), ('Hypno', 63), ('Ivysaur', 53), ('Jigglypuff', 65), ('Jolteon', 64), ('Jynx', 59), ('Kabuto', 56), ('Kabutops', 66), ('Kadabra', 61), ('Kakuna', 67), ('Kangaskhan', 63), ('Kingler', 69), ('Koffing', 65), ('Krabby', 64), ('Lapras', 71), ('Lickitung', 67), ('Machamp', 72), ('Machoke', 51), ('Machop', 53), ('Magikarp', 59), ('Magmar', 59), ('Magnemite', 60), ('Magneton', 59), ('Mankey', 72), ('Marowak', 70), ('Meowth', 70), ('Metapod', 65), ('Mew', 67), ('Mewtwo', 307), ('Moltres', 62), ('MrMime', 59), ('Muk', 71), ('Nidoking', 68), ('Nidoqueen', 66), ('Nidorina', 59), ('Nidorino', 63), ('Ninetales', 74), ('Oddish', 66), ('Omanyte', 55), ('Omastar', 58), ('Onix', 64), ('Paras', 55), ('Parasect', 53), ('Persian', 57), ('Pidgeot', 66), ('Pidgeotto', 63), ('Pidgey', 74), ('Pikachu', 298), ('Pinsir', 63), ('Poliwag', 65), ('Poliwhirl', 64), ('Poliwrath', 63), ('Ponyta', 66), ('Porygon', 55), ('Primeape', 70), ('Psyduck', 159), ('Raichu', 71), ('Rapidash', 83), ('Raticate', 70), ('Rattata', 67), ('Rhydon', 59), ('Rhyhorn', 69), ('Sandshrew', 66), ('Sandslash', 71), ('Scyther', 68), ('Seadra', 67), ('Seaking', 65), ('Seel', 61), ('Shellder', 81), ('Slowbro', 63), ('Slowpoke', 60), ('Snorlax', 69), ('Spearow', 130), ('Squirtle', 280), ('Starmie', 59), ('Staryu', 60), ('Tangela', 63), ('Tauros', 67), ('Tentacool', 57), ('Tentacruel', 57), ('Vaporeon', 68), ('Venomoth', 66), ('Venonat', 57), ('Venusaur', 66), ('Victreebel', 55), ('Vileplume', 67), ('Voltorb', 65), ('Vulpix', 68), ('Wartortle', 61), ('Weedle', 59), ('Weepinbell', 51), ('Weezing', 63), ('Wigglytuff', 67), ('Zapdos', 60), ('Zubat', 49)]
# ['Abra', 'Aerodactyl', 'Alakazam', 'Arbok', 'Arcanine', 'Articuno', 'Beedrill', 'Bellsprout', 'Blastoise', 'Bulbasaur', 'Butterfree', 'Caterpie', 'Chansey', 'Charizard', 'Charmander', 'Charmeleon', 'Clefable', 'Clefairy', 'Cloyster', 'Cubone', 'Dewgong', 'Diglett', 'Ditto', 'Dodrio', 'Doduo', 'Dragonair', 'Dragonite', 'Dratini', 'Drowzee', 'Dugtrio', 'Eevee', 'Ekans', 'Electabuzz', 'Electrode', 'Exeggcute', 'Exeggutor', 'Farfetchd', 'Fearow', 'Flareon', 'Gastly', 'Gengar', 'Geodude', 'Gloom', 'Golbat', 'Goldeen', 'Golduck', 'Golem', 'Graveler', 'Grimer', 'Growlithe', 'Gyarados', 'Haunter', 'Hitmonchan', 'Hitmonlee', 'Horsea', 'Hypno', 'Ivysaur', 'Jigglypuff', 'Jolteon', 'Jynx', 'Kabuto', 'Kabutops', 'Kadabra', 'Kakuna', 'Kangaskhan', 'Kingler', 'Koffing', 'Krabby', 'Lapras', 'Lickitung', 'Machamp', 'Machoke', 'Machop', 'Magikarp', 'Magmar', 'Magnemite', 'Magneton', 'Mankey', 'Marowak', 'Meowth', 'Metapod', 'Mew', 'Mewtwo', 'Moltres', 'MrMime', 'Muk', 'Nidoking', 'Nidoqueen', 'Nidorina', 'Nidorino', 'Ninetales', 'Oddish', 'Omanyte', 'Omastar', 'Onix', 'Paras', 'Parasect', 'Persian', 'Pidgeot', 'Pidgeotto', 'Pidgey', 'Pikachu', 'Pinsir', 'Poliwag', 'Poliwhirl', 'Poliwrath', 'Ponyta', 'Porygon', 'Primeape', 'Psyduck', 'Raichu', 'Rapidash', 'Raticate', 'Rattata', 'Rhydon', 'Rhyhorn', 'Sandshrew', 'Sandslash', 'Scyther', 'Seadra', 'Seaking', 'Seel', 'Shellder', 'Slowbro', 'Slowpoke', 'Snorlax', 'Spearow', 'Squirtle', 'Starmie', 'Staryu', 'Tangela', 'Tauros', 'Tentacool', 'Tentacruel', 'Vaporeon', 'Venomoth', 'Venonat', 'Venusaur', 'Victreebel', 'Vileplume', 'Voltorb', 'Vulpix', 'Wartortle', 'Weedle', 'Weepinbell', 'Weezing', 'Wigglytuff', 'Zapdos', 'Zubat']

# %%
X = [] # List for images
Y = [] # List for labels

# Loop through all classes
for c in classes:
    # We take only classes that we defined in 'imbalanced' list
    if c in imbalanced:
        dir_path = os.path.join(path, c)
        label = imbalanced.index(c) # Our label is an index of class in 'imbalanced' list
        
        # Reading, resizing and adding image and label to lists
        for i in os.listdir(dir_path):
            image = cv.imread(os.path.join(dir_path, i))
            
            try:
                #resized = cv.resize(image, (96, 96)) # Resizing images to (96, 96)
                resized = cv.resize(image, (196, 196)) # Resizing images to (196, 196)
                X.append(resized)
                Y.append(label)
            
            # If we can't read image - we skip it
            except:
                print(os.path.join(dir_path, i), '[ERROR] can\'t read the file')
                continue       
            
print('DONE')
# Out:
# /root/userspace/private/competition/dataset/Venomoth/bb5d47bced6e4e33a77faa17e1eec906.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Nidoqueen/89a9c05292d84aeab91bb105da37e0c0.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Voltorb/94f443d834f94c1e8e6b088d879646d4.gif~c200 [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Graveler/3fe3c6a0bbd14de89092d2c675f743c1.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Fearow/8f2d7986ab76482fb76cac6a91b66de4.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Fearow/2c8d5221e92444f2b9477350e405bc54.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Kingler/a87633dcbf9643319da5d702e2e1a56c.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Scyther/a8734f10941a4deb95fcf7388e4fe8e2.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Exeggutor/f29b4f9fccff4055b167ece6556143cd.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Exeggutor/2b8bc491c5ca4e788999f8ea53617638.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Gyarados/6444e4ec716b44a4959bf97c1e75a935.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Hypno/ea34a7f7c68c467e8bf7240b26e0002c.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Zapdos/c99b2d19544c4cbbacd7711ade660279.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Golduck/bc08a691e7cb41b0bec2adf931dc9634.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Magneton/45e434d002bd44eeb1acbc2decc8ee0f.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Electabuzz/28a02c7a1389471693ff89712f1064f3.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Kabutops/01b54e83745340569cdde1442c8c429f.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Growlithe/f7a87c057dc94a32a0d5aedd1abed088.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Cloyster/ff270ebfab0f46b3b05c3fecd6a15ef9.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Caterpie/dcd36168d2bd470aaca333fb3bdf6bfa.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Poliwag/456c5063598a46a68a60ebcde5647ace.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Mewtwo/ed9eb0e7d3494c6992e06196f5b7cc05.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Venonat/56425d5f66e64584afbfc797b93c7ee5.ico [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Dewgong/e3ecbb47e192470aa8686734b7813b43.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Omastar/1be6e7da1bba4379b298b20013c57b4b.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Omastar/59761964ea084b4c85fc97837cd60fd8.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Machamp/546d68ace3ac414eb671b0e87880d683.svg [ERROR] can't read the file
# /root/userspace/private/competition/dataset/Tentacruel/d6fb0a3046364ea2b49525c6f6b966e5.svg [ERROR] can't read the file
# DONE

# %%
# Counting appearances of each label in labels list
obj = Counter(Y)

# Plotting number of images in each class
fig = plt.figure(figsize = (20, 5))
sns.barplot(x = [imbalanced[i] for i in obj.keys()], y = list(obj.values())).set_title('Number of images in each class')
plt.margins(x=0)
plt.show()

# %%
# Convert list with images to numpy array and reshape it 
#X = np.array(X).reshape(-1, 96, 96, 3)
X = np.array(X).reshape(-1, 196, 196, 3)

# Scaling data in array
X = X / 255.0

# Convert labels to categorical format
y = to_categorical(Y, num_classes = len(imbalanced))

# Splitting data to train and test datasets
# I'll use these datasets only for training, for final predictions I'll use random pictures from internet
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, shuffle = True, random_state = 666)

# %%
# Defining ImageDataGenerator Iinstance
#datagen = ImageDataGenerator(rotation_range = 45, # Degree range for random rotations
#                            zoom_range = 0.2, # Range for random zoom 
#                            horizontal_flip = True, # Randomly flip inputs horizontally
#                            width_shift_range = 0.15, # Range for horizontal shift 
#                            height_shift_range = 0.15, # Range for vertical shift 
#                            shear_range = 0.2) # Shear Intensity
datagen = ImageDataGenerator(
                            #featurewise_center = True, 
                            #featurewise_std_normalization = True,
                            rotation_range = 45, # Degree range for random rotations
                            zoom_range = 0.5, # Range for random zoom 
                            horizontal_flip = True, # Randomly flip inputs horizontally
                            width_shift_range = 0.5, # Range for horizontal shift 
                            height_shift_range = 0.5, # Range for vertical shift 
                            shear_range = 0.2) # Shear Intensity

datagen.fit(X_train)

# This piece of code can be used if you eant to look what your datagen doing with your images
# img = X[600]
# img = img.reshape([-1, 96, 96, 3])

# i = 0
# fig = plt.figure(figsize = (18, 8))

# for i, flow in enumerate(datagen.flow(img, batch_size = 1)):
#     fig.add_subplot(2, 5, i+1)
#     plt.imshow(np.squeeze(flow[:, :, ::-1]))
#     plt.axis('off')
#     i += 1
#     if i >= 10:
#         break

# %%
#model = Sequential()
#model.add(Conv2D(32, 3, padding = 'same', activation = 'relu', input_shape =(96, 96, 3), kernel_initializer = 'he_normal'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(128, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(128, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Conv2D(256, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(Conv2D(256, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
#model.add(BatchNormalization(axis = -1))
#model.add(MaxPooling2D((2, 2)))
#model.add(Dropout(0.25))
#
#model.add(Flatten())
#model.add(Dense(512, activation = 'relu'))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))
#model.add(Dense(256, activation = 'relu'))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))
#model.add(Dense(len(imbalanced), activation = 'softmax'))
#
#model.summary()
#
##checkpoint = ModelCheckpoint('../working/best_model.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#checkpoint = ModelCheckpoint('/Users/nakayama/Desktop/lesson/advanced/work/pokemon/best_model.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#
#model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
##history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 100, validation_data = [X_test, y_test],
##                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])
#history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 10, validation_data = [X_test, y_test],
#                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])

#input_tensor = Input(shape=(96, 96, 3))
input_tensor = Input(shape=(196, 196, 3))
#base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=input_tensor)
base_model = Xception(include_top=False, weights='imagenet', input_tensor=input_tensor)

# 全結合層の新規構築
top_model = base_model.output
top_model = GlobalAveragePooling2D()(top_model)
#top_model = Flatten()(top_model)
top_model = Dense(1024, activation = 'relu')(top_model)
predictions = Dense(len(imbalanced), activation = 'softmax')(top_model)

# ネットワーク定義
model = Model(inputs = base_model.input, outputs = predictions)

print("{}層".format(len(model.layers)))

# block14_sepconv1 層の手前まで freeze
trainable = False
for layer in model.layers:
    if layer.name == 'block14_sepconv1':
        trainable = True
    
    # block14_sepconv1 以降の層は freeze 解除
    layer.trainable = trainable

    # Batch Normalization の freeze 解除
    if layer.name.startswith('batch_normalization'):
        layer.trainable = True
    if layer.name.endswith('bn'):
        layer.trainable = True

##108層までfreeze
#for layer in model.layers[:108]:
#    layer.trainable = False
#
#    # Batch Normalization の freeze解除
#    if layer.name.startswith('batch_normalization'):
#        layer.trainable = True
#    if layer.name.endswith('bn'):
#        layer.trainable = True
#
##109層以降、学習させる
#for layer in model.layers[108:]:
#    layer.trainable = True

model.summary()

checkpoint = ModelCheckpoint('/root/userspace/private/competition/best_model_8.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
#checkpoint = ModelCheckpoint('/root/userspace/private/competition/best_model.hdf5', verbose = 1, monitor = 'val_acc', save_best_only = True)

#model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.compile(optimizer = 'adamax', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# 135層
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 196, 196, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 97, 97, 32)   864         input_2[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 97, 97, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 97, 97, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 95, 95, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 95, 95, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 95, 95, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 95, 95, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 95, 95, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 95, 95, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 95, 95, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 95, 95, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 48, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 48, 48, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 48, 48, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 48, 48, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 48, 48, 128)  0           add_13[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 48, 48, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 48, 48, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 48, 48, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 48, 48, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 48, 48, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 24, 24, 256)  32768       add_13[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 24, 24, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 24, 24, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 24, 24, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 24, 24, 256)  0           add_14[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 24, 24, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 24, 24, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 24, 24, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 24, 24, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 24, 24, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 12, 12, 728)  186368      add_14[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 12, 12, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 12, 12, 728)  2912        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 12, 12, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 12, 12, 728)  0           add_15[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 12, 12, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 12, 12, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 12, 12, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 12, 12, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 12, 12, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 12, 12, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 12, 12, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 12, 12, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 12, 12, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 12, 12, 728)  0           add_16[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 12, 12, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 12, 12, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 12, 12, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 12, 12, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 12, 12, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 12, 12, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 12, 12, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 12, 12, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 12, 12, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 12, 12, 728)  0           add_17[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 12, 12, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 12, 12, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 12, 12, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 12, 12, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 12, 12, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 12, 12, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 12, 12, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 12, 12, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 12, 12, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 12, 12, 728)  0           add_18[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 12, 12, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 12, 12, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 12, 12, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 12, 12, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 12, 12, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 12, 12, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 12, 12, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 12, 12, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 12, 12, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 12, 12, 728)  0           add_19[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 12, 12, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 12, 12, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 12, 12, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 12, 12, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 12, 12, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 12, 12, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 12, 12, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 12, 12, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 12, 12, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 12, 12, 728)  0           add_20[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 12, 12, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 12, 12, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 12, 12, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 12, 12, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 12, 12, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 12, 12, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 12, 12, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 12, 12, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 12, 12, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 12, 12, 728)  0           add_21[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 12, 12, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 12, 12, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 12, 12, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 12, 12, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 12, 12, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 12, 12, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 12, 12, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 12, 12, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 12, 12, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 12, 12, 728)  0           add_22[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 12, 12, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 12, 12, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 12, 12, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 12, 12, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 12, 12, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 12, 12, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 12, 12, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 12, 12, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 12, 12, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 12, 12, 728)  0           add_23[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 12, 12, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 12, 12, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 12, 12, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 12, 12, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 12, 12, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 6, 6, 1024)   745472      add_23[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 6, 6, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 6, 6, 1024)   4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 6, 6, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 6, 6, 1536)   1582080     add_24[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 6, 6, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 6, 6, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 6, 6, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 6, 6, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 6, 6, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         2098176     global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 149)          152725      dense_3[0][0]
# ==================================================================================================
# Total params: 23,112,381
# Trainable params: 7,047,061
# Non-trainable params: 16,065,320
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 30, validation_data = [X_test, y_test],
                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])

# 性能評価
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/30
# 266/266 [==============================] - 133s 501ms/step - loss: 4.3600 - accuracy: 0.1268 - val_loss: 3.0385 - val_accuracy: 0.3015
#
# Epoch 00001: val_accuracy improved from -inf to 0.30145, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 2/30
# 266/266 [==============================] - 129s 484ms/step - loss: 2.8593 - accuracy: 0.3398 - val_loss: 1.8546 - val_accuracy: 0.5265
#
# Epoch 00002: val_accuracy improved from 0.30145 to 0.52649, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 3/30
# 266/266 [==============================] - 129s 484ms/step - loss: 2.1687 - accuracy: 0.4713 - val_loss: 1.4358 - val_accuracy: 0.6334
#
# Epoch 00003: val_accuracy improved from 0.52649 to 0.63338, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 4/30
# 266/266 [==============================] - 129s 484ms/step - loss: 1.8583 - accuracy: 0.5429 - val_loss: 1.2989 - val_accuracy: 0.6718
#
# Epoch 00004: val_accuracy improved from 0.63338 to 0.67182, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 5/30
# 266/266 [==============================] - 128s 483ms/step - loss: 1.6121 - accuracy: 0.5940 - val_loss: 1.2144 - val_accuracy: 0.6864
#
# Epoch 00005: val_accuracy improved from 0.67182 to 0.68636, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 6/30
# 266/266 [==============================] - 129s 484ms/step - loss: 1.4720 - accuracy: 0.6281 - val_loss: 1.2180 - val_accuracy: 0.7065
#
# Epoch 00006: val_accuracy improved from 0.68636 to 0.70652, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 7/30
# 266/266 [==============================] - 129s 484ms/step - loss: 1.3418 - accuracy: 0.6521 - val_loss: 1.0835 - val_accuracy: 0.7234
#
# Epoch 00007: val_accuracy improved from 0.70652 to 0.72339, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 8/30
# 266/266 [==============================] - 129s 484ms/step - loss: 1.1941 - accuracy: 0.6845 - val_loss: 1.1033 - val_accuracy: 0.7351
#
# Epoch 00008: val_accuracy improved from 0.72339 to 0.73511, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 9/30
# 266/266 [==============================] - 129s 484ms/step - loss: 1.1294 - accuracy: 0.7028 - val_loss: 1.0600 - val_accuracy: 0.7506
#
# Epoch 00009: val_accuracy improved from 0.73511 to 0.75059, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 10/30
# 266/266 [==============================] - 129s 484ms/step - loss: 1.0741 - accuracy: 0.7145 - val_loss: 1.0891 - val_accuracy: 0.7478
#
# Epoch 00010: val_accuracy did not improve from 0.75059
# Epoch 11/30
# 266/266 [==============================] - 129s 484ms/step - loss: 1.0278 - accuracy: 0.7221 - val_loss: 1.0861 - val_accuracy: 0.7511
#
# Epoch 00011: val_accuracy improved from 0.75059 to 0.75105, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 12/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.9406 - accuracy: 0.7506 - val_loss: 1.0956 - val_accuracy: 0.7548
#
# Epoch 00012: val_accuracy improved from 0.75105 to 0.75481, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 13/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.9024 - accuracy: 0.7562 - val_loss: 1.0840 - val_accuracy: 0.7581
#
# Epoch 00013: val_accuracy improved from 0.75481 to 0.75809, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 14/30
# 266/266 [==============================] - 128s 483ms/step - loss: 0.8489 - accuracy: 0.7698 - val_loss: 1.1366 - val_accuracy: 0.7525
#
# Epoch 00014: val_accuracy did not improve from 0.75809
# Epoch 15/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.8006 - accuracy: 0.7815 - val_loss: 1.1056 - val_accuracy: 0.7548
#
# Epoch 00015: val_accuracy did not improve from 0.75809
# Epoch 16/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.7926 - accuracy: 0.7869 - val_loss: 1.0728 - val_accuracy: 0.7661
#
# Epoch 00016: val_accuracy improved from 0.75809 to 0.76606, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 17/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.7201 - accuracy: 0.8011 - val_loss: 1.0956 - val_accuracy: 0.7665
#
# Epoch 00017: val_accuracy improved from 0.76606 to 0.76653, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 18/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.7068 - accuracy: 0.8100 - val_loss: 1.0875 - val_accuracy: 0.7736
#
# Epoch 00018: val_accuracy improved from 0.76653 to 0.77356, saving model to /root/userspace/private/competition/best_model_8.hdf5
# Epoch 19/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.6812 - accuracy: 0.8125 - val_loss: 1.1253 - val_accuracy: 0.7614
#
# Epoch 00019: val_accuracy did not improve from 0.77356
# Epoch 20/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.6424 - accuracy: 0.8238 - val_loss: 1.1247 - val_accuracy: 0.7604
#
# Epoch 00020: val_accuracy did not improve from 0.77356
# Epoch 21/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.6457 - accuracy: 0.8231 - val_loss: 1.1797 - val_accuracy: 0.7623
#
# Epoch 00021: val_accuracy did not improve from 0.77356
# Epoch 22/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.6405 - accuracy: 0.8258 - val_loss: 1.1717 - val_accuracy: 0.7647
#
# Epoch 00022: val_accuracy did not improve from 0.77356
# Epoch 23/30
# 266/266 [==============================] - 129s 483ms/step - loss: 0.6008 - accuracy: 0.8360 - val_loss: 1.1990 - val_accuracy: 0.7642
#
# Epoch 00023: val_accuracy did not improve from 0.77356
# Epoch 24/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.5911 - accuracy: 0.8358 - val_loss: 1.2276 - val_accuracy: 0.7651
#
# Epoch 00024: val_accuracy did not improve from 0.77356
# Epoch 25/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.5812 - accuracy: 0.8344 - val_loss: 1.2652 - val_accuracy: 0.7693
#
# Epoch 00025: val_accuracy did not improve from 0.77356
# Epoch 26/30
# 266/266 [==============================] - 129s 483ms/step - loss: 0.5593 - accuracy: 0.8435 - val_loss: 1.2610 - val_accuracy: 0.7642
#
# Epoch 00026: val_accuracy did not improve from 0.77356
# Epoch 27/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.5383 - accuracy: 0.8467 - val_loss: 1.2151 - val_accuracy: 0.7651
#
# Epoch 00027: val_accuracy did not improve from 0.77356
# Epoch 28/30
# 266/266 [==============================] - 129s 483ms/step - loss: 0.5208 - accuracy: 0.8525 - val_loss: 1.2884 - val_accuracy: 0.7689
#
# Epoch 00028: val_accuracy did not improve from 0.77356
# Epoch 29/30
# 266/266 [==============================] - 129s 483ms/step - loss: 0.5037 - accuracy: 0.8560 - val_loss: 1.2303 - val_accuracy: 0.7576
#
# Epoch 00029: val_accuracy did not improve from 0.77356
# Epoch 30/30
# 266/266 [==============================] - 129s 484ms/step - loss: 0.4978 - accuracy: 0.8617 - val_loss: 1.2833 - val_accuracy: 0.7600
#
# Epoch 00030: val_accuracy did not improve from 0.77356
# Test loss: 1.2833308818135751
# Test accuracy: 0.7599624991416931

# %%
# Plot learning curves
fig = plt.figure(figsize = (17, 4))
    
plt.subplot(121)
plt.plot(history.history['accuracy'], label = 'acc')
plt.plot(history.history['val_accuracy'], label = 'val_acc')
#plt.plot(history.history['acc'], label = 'acc')
#plt.plot(history.history['val_acc'], label = 'val_acc')
plt.legend()
plt.grid()
plt.title(f'accuracy')

plt.subplot(122)
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.legend()
plt.grid()
plt.title(f'loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
# Loading weights from best model
#model.load_weights('../working/best_model.hdf5')
model.load_weights('/root/userspace/private/competition/best_model_8.hdf5')

# Saving all model
#model.save('../working/model.hdf5')
model.save('/root/userspace/private/competition/model_8.hdf5')

# %%
mewtwo = ['https://cdn.bulbagarden.net/upload/thumb/7/78/150Mewtwo.png/250px-150Mewtwo.png',
         'https://cdn.vox-cdn.com/thumbor/sZPPvUyKyF97UEU-nNtVnC3LpF8=/0x0:1750x941/1200x800/filters:focal(878x316:1158x596)/cdn.vox-cdn.com/uploads/chorus_image/image/63823444/original.0.jpg',
         'https://images-na.ssl-images-amazon.com/images/I/61j5ozFjJ0L._SL1024_.jpg']

pikachu = ['https://lh3.googleusercontent.com/proxy/DrjDlKlu9YonKbj3iNCJNJ3DGqzy9GjeXXSUv-TcVV4UN9PMCAM5yIkGLPG7wYo3UeA4sq5OmUWM8M6K5hy2KOAhf8SOL3zPH3axb2Xo3HX2XTU8M2xW4X6lVg=w720-h405-rw',
          'https://giantbomb1.cbsistatic.com/uploads/scale_medium/0/6087/2437349-pikachu.png',
          'https://johnlewis.scene7.com/is/image/JohnLewis/237525467']

charmander = ['https://img.pokemondb.net/artwork/large/charmander.jpg',
             'https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P5073/701-03990/P5073_701-03990_01.jpg',
             'https://static.posters.cz/image/750/%D0%A7%D0%B0%D1%88%D0%BA%D0%B0/pokemon-charmander-glow-i72513.jpg']

bulbasaur = ['https://img.pokemondb.net/artwork/large/bulbasaur.jpg',
            'https://ae01.alicdn.com/kf/HTB1aWullxSYBuNjSsphq6zGvVXaR/Big-Size-55-CM-Plush-Toy-Squirtle-Bulbasaur-Charmander-Toy-Sleeping-Pillow-Doll-For-Kid-Birthday.jpg',
            'https://cdn.bulbagarden.net/upload/thumb/f/f7/Bulbasaur_Detective_Pikachu.jpg/250px-Bulbasaur_Detective_Pikachu.jpg']

squirtle = ['https://assets.pokemon.com/assets/cms2/img/pokedex/full/007.png',
           'https://cdn.vox-cdn.com/thumbor/l4cKX7ZWargjs-zlxOSW2WZVgfI=/0x0:2040x1360/1200x800/filters:focal(857x517:1183x843)/cdn.vox-cdn.com/uploads/chorus_image/image/61498573/jbareham_180925_ply0802_0030.1537570476.jpg',
           'https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fblogs-images.forbes.com%2Fdavidthier%2Ffiles%2F2018%2F07%2FSquirtle_Squad.jpg']

test_df = [mewtwo, pikachu, charmander, bulbasaur, squirtle]

# %%
# Lists to store our future data
val_x = []
val_y = []

for i, urls in enumerate(test_df):
    for url in urls:        
        r = requests.get(url, stream = True).raw
        image = np.asarray(bytearray(r.read()), dtype="uint8")
        image = cv.imdecode(image, cv.IMREAD_COLOR)
        val_x.append(image)
        val_y.append(i)

# plt.imshow(image[:, :, ::-1])

# %%
rows = 5
cols = 3

fig = plt.figure(figsize = (25, 25))

for i, j in enumerate(zip(val_x, val_y)): # i - for subplots
    orig = j[0] # Original, not resized image
    label = j[1] # Label for that image
    
    #image = cv.resize(orig, (96, 96)) # Resizing image to (96, 96)
    #image = image.reshape(-1, 96, 96, 3) / 255.0 # Reshape and scale resized image
    image = cv.resize(orig, (196, 196)) # Resizing image to (196, 196)
    image = image.reshape(-1, 196, 196, 3) / 255.0 # Reshape and scale resized image
    preds = model.predict(image) # Predicting image
    pred_class = np.argmax(preds) # Defining predicted class
    
    true_label = f'True class: {imbalanced[label]}'
    pred_label = f'Predicted: {imbalanced[pred_class]} {round(preds[0][pred_class] * 100, 2)}%'
    
    fig.add_subplot(rows, cols, i+1)
    plt.imshow(orig[:, :, ::-1])
    plt.title(f'{true_label}\n{pred_label}')
    plt.axis('off')
    
plt.tight_layout()
